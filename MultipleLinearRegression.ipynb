# %% [markdown]
# # Housing price case study
# In this document I have shown the cases such as
# To identify the variables affecting house prices
# To create a linear model relates House price with other independent variables
# Know the accuracy of the model

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\Machine-Learning-with-Real-World-Projects-master\Machine-Learning-with-Real-World-Projects-master\Section 2\Multiple Linear Regression\Housing.csv")

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    bool
#  1   area              545 non-null    bool
#  2   bedrooms          545 non-null    bool
#  3   bathrooms         545 non-null    bool
#  4   stories           545 non-null    bool
#  5   mainroad          545 non-null    bool
#  6   guestroom         545 non-null    bool
#  7   basement          545 non-null    bool
#  8   hotwaterheating   545 non-null    bool
#  9   airconditioning   545 non-null    bool
#  10  parking           545 non-null    bool
#  11  prefarea          545 non-null    bool
#  12  furnishingstatus  545 non-null    bool
# dtypes: bool(13)
# memory usage: 7.0 KB

# %%
#some categorical columns are having 'yes' and 'no' values. So encode them first

df['mainroad'] = df['mainroad'].map({'yes':1,'no':0})
df['guestroom'] = df['guestroom'].map({'yes':1,'no':0})
df['basement'] = df['basement'].map({'yes':1,'no':0})
df['hotwaterheating'] = df['hotwaterheating'].map({'yes':1,'no':0})
df['airconditioning'] = df['airconditioning'].map({'yes':1,'no':0})
df['prefarea'] = df['prefarea'].map({'yes':1,'no':0})

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
status = pd.get_dummies(df['furnishingstatus'], drop_first=True)

# %%
status
# Out:
#      semi-furnished  unfurnished
# 0                 0            0
# 1                 0            0
# 2                 1            0
# 3                 0            0
# 4                 0            0
# ..              ...          ...
# 540               0            1
# 541               1            0
# 542               0            1
# 543               0            0
# 544               0            1
#
# [545 rows x 2 columns]

# %%
df = pd.concat([df,status], axis=1)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus  semi-furnished  unfurnished
# 0        furnished               0            0
# 1        furnished               0            0
# ...

# %%
df.drop(['furnishingstatus'], axis=1, inplace=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    semi-furnished  unfurnished
# 0               0            0
# 1               0            0
# 2               1            0
# ...

# %%
df['areaperbedrooms'] = df['area']/df['bedrooms']

# %%
df['bbratio'] = df['bathrooms']/df['bedrooms']

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    semi-furnished  unfurnished  areaperbedrooms   bbratio
# 0               0            0           1855.0  0.500000
# ...

# %%
def normalize(x):
    return ( (x-np.min(x))/(max(x)-min(x)))

df = df.apply(normalize)

# %%
df.head()
# Out:
#       price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 0  1.000000  0.396564       0.6   0.333333  0.666667       1.0        0.0
# 1  0.909091  0.502405       0.6   1.000000  1.000000       1.0        0.0
# 2  0.909091  0.571134       0.4   0.333333  0.333333       1.0        0.0
# 3  0.906061  0.402062       0.6   0.333333  0.333333       1.0        0.0
# 4  0.836364  0.396564       0.6   0.000000  0.333333       1.0        1.0
#
#    basement  hotwaterheating  airconditioning   parking  prefarea  \
# 0       0.0              0.0              1.0  0.666667       1.0
# 1       0.0              0.0              1.0  1.000000       0.0
# 2       1.0              0.0              0.0  0.666667       1.0
# 3       1.0              0.0              1.0  1.000000       1.0
# 4       1.0              0.0              1.0  0.666667       0.0
#
#    semi-furnished  unfurnished  areaperbedrooms  bbratio
# 0             0.0          0.0         0.237016      0.4
# ...

# %%
y=df['price']

# %%
y
# Out:
# 0      1.000000
# 1      0.909091
# 2      0.909091
# 3      0.906061
# 4      0.836364
#          ...
# 540    0.006061
# 541    0.001485
# 542    0.000000
# 543    0.000000
# 544    0.000000
# Name: price, Length: 545, dtype: float64

# %%
X = df.iloc[:, 1:]
y = df.iloc[:,:-15]

# %%
X.columns
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom',
#        'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefarea',
#        'semi-furnished', 'unfurnished', 'areaperbedrooms', 'bbratio'],
#       dtype='object')

# %%
y.columns
# Out:
# Index(['price'], dtype='object')

# %% [markdown]
# Training data is the set of the data on which the actual training takes place.
# Validation split helps to improve the model performance by fine-tuning the model after each epoch.
# The test set informs us about the final accuracy of the model after completing the training phase.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.7, random_state=100)

# %%
import statsmodels.api as sm
x_train = sm.add_constant(x_train)
lm_1 = sm.OLS(y_train,x_train).fit()

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.656
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     18.72
# Date:                Sun, 16 Jan 2022   Prob (F-statistic):           5.42e-27
# Time:                        01:08:12   Log-Likelihood:                 146.14
# No. Observations:                 163   AIC:                            -260.3
# Df Residuals:                     147   BIC:                            -210.8
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0485      0.140      0.348      0.728      -0.227       0.324
# ...
